# %%
import pandas as pd


df = pd.read_csv('HomeC.csv', dtype='unicode')
# print(df.head(3))

# %%
'''
print(df.columns) # read headers
print(df[['time','use [kW]', 'gen [kW]'] ][0:5]) # printing columns
print("-----------------------------------------------------")
print(df.iloc[1]) # printing rows
print("-----------------------------------------------------")
print(df.iloc[2,1]) # reading a specific location (row number, column number)
print("-----------------------------------------------------")
for index, row in df.iterrows():
    print(index, row['time'])

'''

df.loc[df['visibility']==10]
# Out:
# Empty DataFrame
# Columns: [time, use [kW], gen [kW], House overall [kW], Dishwasher [kW], Furnace 1 [kW], Furnace 2 [kW], Home office [kW], Fridge [kW], Wine cellar [kW], Garage door [kW], Kitchen 12 [kW], Kitchen 14 [kW], Kitchen 38 [kW], Barn [kW], Well [kW], Microwave [kW], Living room [kW], Solar [kW], temperature, icon, humidity, visibility, summary, apparentTemperature, pressure, windSpeed, cloudCover, windBearing, precipIntensity, dewPoint, precipProbability]
# Index: []
#
# [0 rows x 32 columns]

# %%
df.describe()
# Out:
#               time use [kW]     gen [kW] House overall [kW] Dishwasher [kW]  \
# count       503911   503910       503910             503910          503910
# unique      503911   130103        29904             130103            9595
# top     1451624400   0.0008  0.003416667             0.0008               0
# freq             1      132         8260                132          182720
#
#        Furnace 1 [kW] Furnace 2 [kW] Home office [kW]  Fridge [kW]  \
# count          503910         503910           503910       503910
# unique          28755          28700            23272        13986
# top           0.02035    0.064233333      0.042533333  0.005133333
# freq             5805           1187             1876        15963
#
#        Wine cellar [kW]  ... visibility summary apparentTemperature pressure  \
# count            503910  ...     503910  503910              503910   503910
# unique            10738  ...        705      18                5295     3017
# ...

# %%
df.sort_values('time')
# Out:
#               time     use [kW]     gen [kW] House overall [kW]  \
# 0       1451624400  0.932833333  0.003483333        0.932833333
# 1       1451624401  0.934333333  0.003466667        0.934333333
# 2       1451624402  0.931816667  0.003466667        0.931816667
# 3       1451624403      1.02205  0.003483333            1.02205
# 4       1451624404       1.1394  0.003466667             1.1394
# ...            ...          ...          ...                ...
# 503906  1452128306  1.599333333  0.003233333        1.599333333
# 503907  1452128307  1.924266667  0.003216667        1.924266667
# 503908  1452128308       1.9782  0.003216667             1.9782
# 503909  1452128309      1.99095  0.003233333            1.99095
# 503910           \          NaN          NaN                NaN
#
#        Dishwasher [kW] Furnace 1 [kW] Furnace 2 [kW] Home office [kW]  \
# 0             3.33E-05         0.0207    0.061916667      0.442633333
# ...
